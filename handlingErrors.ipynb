# %%
age = input("enter age:")

# %%
age
# Out:
# 'seyma'

# %% [markdown]
# ### try-except

# %%
try:
    myAge= int(input("enter age:"))
    print(myAge*2)
except ValueError:
    print("enter your age!!!!")
# Out:
# enter your age:
