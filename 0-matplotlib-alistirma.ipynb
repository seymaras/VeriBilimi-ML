# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints= np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints)

# %%
xp = np.array([1,2,3,4,5,6,])
yp=np.array([3,7,2,4,5,9])

plt.plot(xp,yp)
plt.show()

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints)

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker="*")

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints, ":r")

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints, "o-")

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints, "-.")

# %%
# "--", ":", "-"

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints, marker="o", ms=20)

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker="o", ms=10, mec="r")

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker="o",ms=20,mfc="r")

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker="o",ms=20, mec="r",mfc="r")

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')

# %%
ypoints = np.array([3,8,1,10,5,7])

plt.plot(ypoints, linestyle="dotted")

# %%
ypoints = np.array([3,8,1,10,5,7])

plt.plot(ypoints, linestyle="dashed")

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints,color="r")

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints, linewidth="20")

# %%
y1 = np.array([4,2,6,8,1])
y2 = np.array([6,2,11,9])

plt.plot(y1)
plt.plot(y2)

# %%
x11 = np.array([0, 1, 2, 3])
y11 = np.array([3, 8, 1, 10])
x22 = np.array([0, 1, 2, 3])
y22 = np.array([6, 2, 7, 11])

plt.plot(x11,y11,x22,y22)
# Out:
# [<matplotlib.lines.Line2D at 0x113ede3d0>,
#  <matplotlib.lines.Line2D at 0x113ede4c0>]

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# Text(0, 0.5, 'Calorie Burnage')

# %%
font1={"family":"serif","color":"blue","size":20}
font2={"family":"serif","color":"darkred","size":15}

plt.title("Sports Watch Data", fontdict=font1)
plt.xlabel("Average Pulse", fontdict=font2)
plt.ylabel("Calorie Burnage", fontdict= font2)
plt.plot(x,y)

# %%
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

# %%
plt.plot(x,y)
plt.title("Sports Watch Data", fontdict= font1)
plt.title("Average Pulse", fontdict=font2)
# Out:
# Text(0.5, 1.0, 'Average Pulse')

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)
plt.grid()

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)
plt.grid(axis="x")

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)
plt.grid(axis="y")

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)
plt.grid(color="green", linestyle="--",linewidth="0.5")

# %%
a= np.array([0,1,2,3])
b= np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(a,b)

a= np.array([0,1,2,3])
b= np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(a,b)

# %%
a = np.array([0, 1, 2, 3])
b = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(a,b)

a = np.array([0, 1, 2, 3])
b = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(a,b)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [167.27541502 148.50409245 178.11331319 171.77473571 175.95324742
#  164.02383743 169.94815432 176.20607726 168.66936481 168.79272261
#  172.76921381 170.10930733 180.38018424 174.3030243  166.87878825
#  167.6232278  185.06792963 181.52088464 176.9879827  172.1444892
#  166.36428421 166.53783474 163.99933463 168.0899445  167.27851517
#  164.10288884 172.51912356 170.4705199  185.90842587 153.2735981
#  181.0515974  171.31070679 167.68773442 176.25531514 172.50634086
#  187.69469945 183.41240752 194.23271916 171.26865152 177.04444552
#  178.21997765 160.83335121 167.44728527 152.54696311 161.1207126
