# %%
import pandas as pd

# %%
import numpy as np

# %%
data=np.random.randn(4,3)

# %%
data
# Out:
# array([[ 1.25229085, -1.52671853, -0.65755561],
#        [-0.20995695,  0.35301545,  0.02005286],
#        [ 0.96912361,  0.14241046, -0.55709832],
#        [ 0.84901604, -0.97406009, -0.18807392]])

# %%
data_frame=pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0  1.252291 -1.526719 -0.657556
# 1 -0.209957  0.353015  0.020053
# 2  0.969124  0.142410 -0.557098
# 3  0.849016 -0.974060 -0.188074

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df = pd.DataFrame(data,index = ["Atil","Ayse","Ali","Veli"],columns=["Salary","Age","Seniority"])

# %%
new_df
# Out:
#         Salary       Age  Seniority
# Atil  1.252291 -1.526719  -0.657556
# Ayse -0.209957  0.353015   0.020053
# Ali   0.969124  0.142410  -0.557098
# Veli  0.849016 -0.974060  -0.188074

# %%
new_df["Age"]
# Out:
# Atil   -1.526719
# Ayse    0.353015
# Ali     0.142410
# Veli   -0.974060
# Name: Age, dtype: float64

# %%
new_df["Salary"]
# Out:
# Atil    1.252291
# Ayse   -0.209957
# Ali     0.969124
# Veli    0.849016
# Name: Salary, dtype: float64

# %%
new_df[["Age","Salary"]]
# Out:
#            Age    Salary
# Atil -1.526719  1.252291
# Ayse  0.353015 -0.209957
# Ali   0.142410  0.969124
# Veli -0.974060  0.849016

# %%
new_df.loc["Atil"]
# Out:
# Salary       1.252291
# Age         -1.526719
# Seniority   -0.657556
# Name: Atil, dtype: float64

# %%
new_df.iloc[0]
# Out:
# Salary       1.252291
# Age         -1.526719
# Seniority   -0.657556
# Name: Atil, dtype: float64

# %%
new_df.iloc[1]
# Out:
# Salary      -0.209957
# Age          0.353015
# Seniority    0.020053
# Name: Ayse, dtype: float64

# %%
new_df.iloc[: 1]
# Out:
#         Salary       Age  Seniority
# Atil  1.252291 -1.526719  -0.657556

# %%
new_df["Extra"]=10

# %%
new_df
# Out:
#         Salary       Age  Seniority  Extra
# Atil  1.252291 -1.526719  -0.657556     10
# Ayse -0.209957  0.353015   0.020053     10
# Ali   0.969124  0.142410  -0.557098     10
# Veli  0.849016 -0.974060  -0.188074     10

# %%
new_df.drop("Extra", axis=1)
# Out:
#         Salary       Age  Seniority
# Atil  1.252291 -1.526719  -0.657556
# Ayse -0.209957  0.353015   0.020053
# Ali   0.969124  0.142410  -0.557098
# Veli  0.849016 -0.974060  -0.188074

# %%
new_df
# Out:
#         Salary       Age  Seniority  Extra
# Atil  1.252291 -1.526719  -0.657556     10
# Ayse -0.209957  0.353015   0.020053     10
# Ali   0.969124  0.142410  -0.557098     10
# Veli  0.849016 -0.974060  -0.188074     10

# %%
new_df.drop("Ayse")
# Out:
#         Salary       Age  Seniority  Extra
# Atil  1.252291 -1.526719  -0.657556     10
# Ali   0.969124  0.142410  -0.557098     10
# Veli  0.849016 -0.974060  -0.188074     10

# %%
new_df
# Out:
#         Salary       Age  Seniority  Extra
# Atil  1.252291 -1.526719  -0.657556     10
# Ali   0.969124  0.142410  -0.557098     10
# Veli  0.849016 -0.974060  -0.188074     10

# %%
new_df.loc["Ali"]
# Out:
# Salary        0.969124
# Age           0.142410
# Seniority    -0.557098
# Extra        10.000000
# Name: Ali, dtype: float64

# %%
new_df.loc["Ali"]["Salary"]
# Out:
# np.float64(0.9691236118862703)

# %%
new_df.loc["Ali","Salary"]
# Out:
# np.float64(0.9691236118862703)

# %%
new_df.loc["Ali","Salary"]=1000

# %%
new_df
# Out:
#            Salary       Age  Seniority  Extra
# Atil     1.252291 -1.526719  -0.657556     10
# Ali   1000.000000  0.142410  -0.557098     10
# Veli     0.849016 -0.974060  -0.188074     10

# %%
boolean_frame =new_df > 0

# %%
new_df[boolean_frame]
# Out:
#            Salary      Age  Seniority  Extra
# Atil     1.252291      NaN        NaN     10
# Ali   1000.000000  0.14241        NaN     10
# Veli     0.849016      NaN        NaN     10

# %%
new_df[new_df>0]
# Out:
#            Salary      Age  Seniority  Extra
# Atil     1.252291      NaN        NaN     10
# Ali   1000.000000  0.14241        NaN     10
# Veli     0.849016      NaN        NaN     10

# %%
new_df[new_df["Salary"]>1]
# Out:
#            Salary       Age  Seniority  Extra
# Atil     1.252291 -1.526719  -0.657556     10
# Ali   1000.000000  0.142410  -0.557098     10

# %%
new_df
# Out:
#            Salary       Age  Seniority  Extra
# Atil     1.252291 -1.526719  -0.657556     10
# Ali   1000.000000  0.142410  -0.557098     10
# Veli     0.849016 -0.974060  -0.188074     10

# %%
new_df.reset_index()
# Out:
#   index       Salary       Age  Seniority  Extra
# 0  Atil     1.252291 -1.526719  -0.657556     10
# 1   Ali  1000.000000  0.142410  -0.557098     10
# 2  Veli     0.849016 -0.974060  -0.188074     10

# %%
reset_frame = new_df.reset_index()

# %%
reset_frame
# Out:
#   index       Salary       Age  Seniority  Extra
# 0  Atil     1.252291 -1.526719  -0.657556     10
# 1   Ali  1000.000000  0.142410  -0.557098     10
# 2  Veli     0.849016 -0.974060  -0.188074     10

# %%
reset_frame.iloc[0]
# Out:
# index            Atil
# Salary       1.252291
# Age         -1.526719
# Seniority   -0.657556
# Extra              10
# Name: 0, dtype: object

# %%
reset_frame.iloc[1]
# Out:
# index             Ali
# Salary         1000.0
# Age           0.14241
# Seniority   -0.557098
# Extra              10
# Name: 1, dtype: object

# %%
new_indices = ["Ati", "Zey", "Meh"]

# %%
new_df["NewIndex"] = new_indices

# %%
new_df
# Out:
#            Salary       Age  Seniority  Extra NewIndex
# Atil     1.252291 -1.526719  -0.657556     10      Ati
# Ali   1000.000000  0.142410  -0.557098     10      Zey
# Veli     0.849016 -0.974060  -0.188074     10      Meh

# %%
new_df.set_index("NewIndex", inplace=True)

# %%
new_df
# Out:
#                Salary       Age  Seniority  Extra
# NewIndex
# Ati          1.252291 -1.526719  -0.657556     10
# Zey       1000.000000  0.142410  -0.557098     10
# Meh          0.849016 -0.974060  -0.188074     10

# %%
new_df.loc["Ati"]
# Out:
# Salary        1.252291
# Age          -1.526719
# Seniority    -0.657556
# Extra        10.000000
# Name: Ati, dtype: float64

# %%
# multi index

# %%
first_index = ["Simpson", "Simpson", "Simpson", "South Park", "South Park", "South Park"]

# %%
inner_index= ["Homer", "Marge", "Bart", "Cartman", "Kenny", "Kyle"]

# %%
zipped_index = list(zip(first_index, inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Marge'),
#  ('Simpson', 'Bart'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',   'Marge'),
#             (   'Simpson',    'Bart'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values, index=zipped_index, columns=["Age", "Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Marge    1.0     1.0
#            Bart     1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Marge      1.0
#             Bart       1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
big_df.loc["Simpson"]
# Out:
#        Age  Salary
# Homer  1.0     1.0
# Marge  1.0     1.0
# Bart   1.0     1.0

# %%
big_df.loc["Simpson"].loc["Homer"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Homer, dtype: float64
