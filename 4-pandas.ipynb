# %%
import numpy as np

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 15.0 MB/s eta 0:00:00 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
grades = {"Atil":50,"Ayse":60,"Ali":70,"Veli":80,"Selami":90}

# %%
pd.Series(grades)
# Out:
# Atil      50
# Ayse      60
# Ali       70
# Veli      80
# Selami    90
# dtype: int64

# %%
names=["Atil","Ayse","Ali","Veli","Selami"]
grades=[50,60,70,80,90]

# %%
pd.Series(names)
# Out:
# 0      Atil
# 1      Ayse
# 2       Ali
# 3      Veli
# 4    Selami
# dtype: object

# %%
pd.Series(grades)
# Out:
# 0    50
# 1    60
# 2    70
# 3    80
# 4    90
# dtype: int64

# %%
pd.Series(names,grades)
# Out:
# 50      Atil
# 60      Ayse
# 70       Ali
# 80      Veli
# 90    Selami
# dtype: object

# %%
pd.Series(grades,names)
# Out:
# Atil      50
# Ayse      60
# Ali       70
# Veli      80
# Selami    90
# dtype: int64

# %%
pd.Series(data=grades,index=names)
# Out:
# Atil      50
# Ayse      60
# Ali       70
# Veli      80
# Selami    90
# dtype: int64

# %%
# with numpy

# %%
numpy_array=np.array([50,60,70,80,90])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    60
# 2    70
# 3    80
# 4    90
# dtype: int64

# %%
#arithmetic

# %%
contest_result1 = pd.Series(data=[10,5,100], index=["Atil","Ayse","Ali"])

# %%
contest_result2= pd.Series(data=[20,50,100], index=["Atil","Ayse","Ali"])

# %%
contest_result1
# Out:
# Atil     10
# Ayse      5
# Ali     100
# dtype: int64

# %%
contest_result2["Ayse"]
# Out:
# np.int64(50)

# %%
final_result=contest_result1+contest_result2

# %%
final_result
# Out:
# Atil     30
# Ayse     55
# Ali     200
# dtype: int64

# %%
contest_result1*contest_result2
# Out:
# Atil      200
# Ayse      250
# Ali     10000
# dtype: int64

# %%
different_series=pd.Series([20,30,40,50],["a","b","c","d"])

# %%
different_series
# Out:
# a    20
# b    30
# c    40
# d    50
# dtype: int64

# %%
different_series2 =pd.Series([10,20,30,40],["a","c","f","g"])

# %%
different_series2
# Out:
# a    10
# c    20
# f    30
# g    40
# dtype: int64

# %%
different_series+different_series2
# Out:
# a    30.0
# b     NaN
# c    60.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
